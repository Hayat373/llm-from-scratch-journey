# %%
import torch
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer
import warnings
warnings.filterwarnings("ignore")

print("Hugging Face setup complete!")
# Out:
# Hugging Face setup complete!

# %%
generator = pipeline('text-generation', model='gpt2', device=0 if torch.cuda.is_available() else -1)

result = generator(
    "Once upon a time in Ethiopia",
    max_new_tokens=150,
    temperature=0.8,
    top_k=50,
    pad_token_id=50256
)

print(result[0]['generated_text'])
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'top_k', 'max_new_tokens', 'temperature', 'pad_token_id'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Once upon a time in Ethiopia, I went to visit two African-American friends. One was white and had a child with HIV, a child I had never met, and had also never heard of. The other was black. They were both black, and they liked each other really. They liked each other. They were good friends, and they liked each other. And then they had a child.
#
# The first thing we did was speak about HIV, and I told her, "This is an African-American girl. She has HIV, but she's not a white person, and she's white. You can't be a white person and say, 'This is an African-American girl.'" And she said, "Okay, but you can be just white

# %%
# 2. Manual Loading (Better Control)
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print(f"Model {model_name} loaded successfully!")
print(f"Model parameters: {model.num_parameters():,}")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Model gpt2 loaded successfully!
# Model parameters: 124,439,808

# %%
# 3. Text Generation with Manual Control
prompt = "The future of AI in Africa is"
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

outputs = model.generate(
    inputs.input_ids,
    max_new_tokens=200,
    temperature=0.7,
    top_k=50,
    top_p=0.95,
    do_sample=True,
    pad_token_id=tokenizer.eos_token_id
)

generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# [transformers] The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The future of AI in Africa is uncertain, but the next generation of artificial intelligence will be able to solve some of the world's most pressing challenges.
#
# It is likely that in the next few years, the next generation of AI will be capable of solving some of the world's most pressing challenges.
#
# "The next generation of AI will be able to solve some of the world's most pressing challenges, including global warming, the environment, climate change, the health of the planet and the security of human lives," said Prof. D.V. Zuksen, a senior researcher at the University of South Carolina in Chapel Hill, who was not involved in the study.
#
# The report was published in the journal Science in September and is the first to examine the impact of artificial intelligence on human health.
#
# The paper, titled "The impacts of artificial intelligence on human health in the 21st century," will be published in the journal Social Science & Medicine in November.
#
# The researchers focused on how AI

# %%
# 4. Try Different Models
models_to_try = [
    "gpt2",
    "distilgpt2",
    "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
]

for m in models_to_try[:2]:
    print(f"\n--- Testing {m} ---")
    try:
        pipe = pipeline('text-generation', model=m, max_new_tokens=100)
        print(pipe("Artificial Intelligence will ")[0]['generated_text'])
    except:
        print("Model too big for current setup")
# Out:
# --- Testing gpt2 ---
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial Intelligence will  have to be able to learn from our past, and we need to learn from our past to have the ability to learn from our future. It's a great question.
# The best way to do this is through a new approach. Instead of only learning new things, we can choose to learn from our past. That's the most common way to learn, but also the most effective. We can learn from the past. We can learn from the future!
# But this is not an easy
#
# --- Testing distilgpt2 ---
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial Intelligence will   be using a device that can be used as a tool to help users track users. This could be the first time in a generation that a machine has ever been used for such a purpose.›
#
#
#
# Now we› are learning to use artificial intelligence to make a living.
# One of the biggest challenges facing artificial intelligence is it doesn›t have access to any data on users. Even if it works, it›s just too complex, and it can�
